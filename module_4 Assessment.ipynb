# %% [markdown]
# # Class Exercise
#
# ### In this exercise, you will practice using NumPy, a fundamental library in Python for numerical computing.

# %% [markdown]
# What is NumPy in Python?
#
# a) A web framework
#
# b) A package for numerical computing
#
# c) A text editor
#
# d) A database management tool

# %%
answer_q1 = "b"
answer_q1
#raise NotImplementedError()
# Out:
# 'b'

# %% [markdown]
# Why do we use NumPy instead of Python lists for numerical operations?
#
# a) NumPy arrays are slower than lists
#
# b) NumPy arrays take less memory and allow fast operations
#
# c) NumPy cannot handle large datasets
#
# d) NumPy does not support vectorized operations

# %%
answer_q2 = "b"
answer_q2 

#raise NotImplementedError()
# Out:
# 'b'

# %% [markdown]
# Which command is used to install NumPy?
#
# a) pip install numpy
#
# b) import numpy
#
# c) numpy.install()
#
# d) pip numpy

# %%
answer_q3 = "a"
answer_q3

# raise NotImplementedError()
# Out:
# 'a'

# %% [markdown]
# Which of the following correctly imports NumPy?
#
# a) import numpy as np
#
# b) from numpy import np
#
# c) import numpy.numpy as np
#
# d) use numpy

# %%
answer_q4 = "a"
answer_q4
# raise NotImplementedError()
# Out:
# 'a'

# %% [markdown]
# What is the default data type of a NumPy array created from [1, 2, 3]?
#
# a) float64
#
# b) bool
#
# c) int64
#
# d) str

# %%
answer_q5 = "c"
answer_q5

# raise NotImplementedError()
# Out:
# 'c'

# %% [markdown]
# Which attribute gives the number of dimensions of a NumPy array?
#
# a) shape
#
# b) size
#
# c) dtype
#
# d) ndim

# %%
# YOUR ANSWER (write only a, b, c or d)
answer_q6 = "d"
answer_q6 

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# Which attribute gives the total number of elements in a NumPy array?
#
# a) size
#
# b) shape
#
# c) dtype
#
# d) ndim

# %%
# YOUR ANSWER (write only a, b, c or d)
answer_q7 = ""

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# Which of the following correctly changes the data type of a NumPy array **arr** to float?
#
# a) arr.astype(float)
#
# b) arr.dtype(float)
#
# c) arr.change(float)
#
# d) arr.float()

# %%
# YOUR ANSWER (write only a, b, c or d)
answer_q8 = ""

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Coding Questions

# %% [markdown]
# #### Create a 1D NumPy array called **a** containing the numbers [10, 20, 30, 40] and check the data type of the array.

# %%
# TODO: Create the array and check its data type
import numpy as np


# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# #### Create a 2D NumPy array called **b** with numbers 1, 2, 3, 4 and specify the data type as float.

# %%
import numpy as np


# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# #### Using the data above change the data type of the array to integer:

# %%
import numpy as np


# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# #### Check the array attributes of the following array: [[1, 2, 3], [4, 5, 6]].

# %%
# check for the size, shape, ndim, data type
import numpy as np


# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Pressure Sensor Data

# %%
import numpy as np

np.random.seed(43)

pressure_data = np.random.uniform(
    low=100.0,
    high=500.0,
    size=100_000
)

# %% [markdown]
# ### Simulate your Data
#
# Create a uniform pressure data of 500000 rows with low = 100 and high = 500 called `pressure_data`. This stores the total number of pressure observations. Set the seed to 43

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Minimum and maximum pressure
#
# Create two variables `p_min` and `p_max` containing the minimum and maximum pressure values.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Compute Mean pressure and standard deviation
#
# - Compute the mean pressure and store it in a variable called `p_mean`.
# - Compute the standard deviation of the pressure values and store it in `p_std`.
# - Compute the 5th percentile of the pressure values and store it in `p5`.
# - Compute the 05th percentile of the pressure values and store it in `p95`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Z-score normalisation
#
# Create a new array called `pressure_z` containing the z-scores of the pressure values.
#
# Use the formula:
#
# 𝑧 = (𝑥 − 𝜇)/𝜎
#
# where:
#
# z = `pressure_z`
#
# x = `pressure_data`
#
# 𝜇 = `mean`
#
# 𝜎 = `standard deviation`

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Identify extreme readings
#
# Create an array called `extreme_pressure` that contains all values whose `absolute` z-score is greater than 1.5.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Count the extreme readings
#
# From the array `extreme_pressure` count the total number of outliers and stoer it as `total_outliers`

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Visulaise your plot
#
# Create a histogram showing the normal pressure readings and outliers

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# YOUR CODE HERE
raise NotImplementedError()
